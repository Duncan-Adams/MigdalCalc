# %%
from migdalcalc import migdalcalc
import matplotlib.pyplot as plt
import numpy as np

# %%
Si_migdal = migdalcalc.migdalcalc(target='Si-28')

# %%
dE_range = np.geomspace(9, 7e4, 1000)
plt.plot(Si_migdal.mig.dPdEe(dE_range, 'ibe'))
plt.yscale('log')
plt.show()
